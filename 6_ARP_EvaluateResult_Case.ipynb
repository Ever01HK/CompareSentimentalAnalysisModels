# %%
import numpy as np
from sklearn.metrics import (
    confusion_matrix,
    ConfusionMatrixDisplay,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
)
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pandas as pd
import seaborn as sns

# %%
# Load original result data of model1
result_data = pd.read_csv(
    "Result_CaseModel_rvNeutral.csv", encoding="UTF-8"
)

# %%
# Comparison matrix of ms_today
y_true = result_data["Label"] # Ground truth
y_pred = result_data["Sentiment_Title"]  # Predictions

# Calculate metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred , average="binary", pos_label='Positive')
recall = recall_score(y_true, y_pred , average="binary", pos_label='Positive')
f1 = f1_score(y_true, y_pred , average="binary", pos_label='Positive')
conf_matrix = confusion_matrix(y_true, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)

sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")

title_font = {
    'fontsize': 12,
    'fontweight': 'bold'
}
plt.title("Confusion matrix of original data for Case's model", fontdict=title_font, pad=20)
plt.show()
# Out:
# Accuracy: 0.9459459459459459
# Precision: 0.974559686888454
# Recall: 0.9343339587242027
# F1 Score: 0.9540229885057471
# Confusion Matrix:
#  [[342  13]
#  [ 35 498]]

# %%
# comparison matrix of ms_today
y_true = result_data["Label"] # Ground truth
y_pred = result_data["Sentiment_PreprocessedTitle"]  # Predictions

# Calculate metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred , average="binary", pos_label='Positive')
recall = recall_score(y_true, y_pred , average="binary", pos_label='Positive')
f1 = f1_score(y_true, y_pred , average="binary", pos_label='Positive')
conf_matrix = confusion_matrix(y_true, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)

sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")

title_font = {
    'fontsize': 12,
    'fontweight': 'bold'
}
plt.title("Confusion matrix of pre-processed data for Case's model", fontdict=title_font, pad=20)
plt.show()
# Out:
# Accuracy: 0.8468468468468469
# Precision: 0.8899803536345776
# Recall: 0.849906191369606
# F1 Score: 0.8694817658349329
# Confusion Matrix:
#  [[299  56]
#  [ 80 453]]

# %%
# Evaluate predict value (original data) with Actual stock price
y_true = result_data["ActualValue"] # Ground truth
y_pred = result_data["Number_Sent_Title"]  # Predictions

# Calculate metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred , average="binary", pos_label=1)
recall = recall_score(y_true, y_pred , average="binary", pos_label=1)
f1 = f1_score(y_true, y_pred , average="binary", pos_label=1)
conf_matrix = confusion_matrix(y_true, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)

sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")

title_font = {
    'fontsize': 12,
    'fontweight': 'bold'
}
plt.title("Confusion matrix of original number data for Case's model", fontdict=title_font, pad=20)
plt.show()
# Out:
# Accuracy: 0.6655405405405406
# Precision: 0.7045009784735812
# Recall: 0.7114624505928854
# F1 Score: 0.7079646017699115
# Confusion Matrix:
#  [[231 151]
#  [146 360]]

# %%
# Evaluate predict value (original data) with Actual stock price
y_true = result_data["ActualValue"] # Ground truth
y_pred = result_data["Number_Sent_Preprocessed"]  # Predictions

# Calculate metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred , average="binary", pos_label=1)
recall = recall_score(y_true, y_pred , average="binary", pos_label=1)
f1 = f1_score(y_true, y_pred , average="binary", pos_label=1)
conf_matrix = confusion_matrix(y_true, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)

sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")

title_font = {
    'fontsize': 12,
    'fontweight': 'bold'
}
plt.title("Confusion matrix of preprocessed number data for Case's model", fontdict=title_font, pad=20)
plt.show()
# Out:
# Accuracy: 0.6227477477477478
# Precision: 0.6679764243614931
# Recall: 0.6719367588932806
# F1 Score: 0.6699507389162561
# Confusion Matrix:
#  [[213 169]
#  [166 340]]
